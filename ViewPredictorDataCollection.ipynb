# %% [markdown]
# # REFERENCES:
#     All API calls are referred from this source: https://developers.google.com/youtube/v3/docs/videos
#     Progress Bar code referenced from:
#         https://github.com/allenwang28/YouTube-Virality-Predictor/blob/master/scripts/get_last_video_count.ipynb
#     Emoticon Removal:
#         http://stackoverflow.com/a/13752628/6762004

# %%
from googleapiclient.discovery import build
from googleapiclient.errors import HttpError
import requests
import pandas as pd
from pathlib import Path
from textblob import TextBlob
import re

# %%
DEVELOPER_KEY = ''
YOUTUBE_API_SERVICE_NAME = 'youtube'
YOUTUBE_API_VERSION = 'v3'

# %%
#METHOD 1
#FUNCTION: Performs keyword search for all the channels matching the keyword
#returnslist of channelIDs
def youtube_channel_search(options, num_of_pages):
    youtube = build(YOUTUBE_API_SERVICE_NAME, YOUTUBE_API_VERSION,developerKey=DEVELOPER_KEY)

    channelids = []  
    #print(2)
    for page in range(0,int(num_of_pages)):
        if page==0:
            #print(3)
            search_response = youtube.search().list(
                q=options.q,
                type='channel',
                part='id,snippet',
                relevanceLanguage='en',
                maxResults=options.max_results
                ).execute()
            #print(search_response)
            next_page_token=search_response.get('nextPageToken')
            for search_result in search_response.get('items', []):
                #print(5)
                if search_result['id']['kind'] == 'youtube#channel':
                    channelids.append('%s' % (search_result['id']['channelId']))
                    #print(6)

        else:
            if next_page_token is not None:
                search_response = youtube.search().list(
                    q=options.q,
                    type='channel',
                    pageToken=next_page_token,
                    part='id,snippet',
                    relevanceLanguage='en',
                    maxResults=options.max_results
                    ).execute()
                next_page_token=search_response.get('nextPageToken')
                for search_result in search_response.get('items', []):
                    if search_result['id']['kind'] == 'youtube#channel':
                        channelids.append('%s' % (search_result['id']['channelId']))

    return channelids

# %%
#METHOD 2
#Function: Converts duration of videos to seconds
#PURPOSE: since the duration format provided by youtube is of type PT1H1M1S
def convert_to_seconds(duration):
    h=0
    m=0
    s=0
    if 'H' not in duration:
        if 'M' not in duration:
            if 'S' in duration:
                s=duration.split('S')[0]
        else:
            m=duration.split('M')[0]
            if 'S' in duration:
                s=duration.split('M')[1].split('S')[0]
    else:
        h=duration.split('H')[0]
        if 'M' not in duration:
            if 'S' in duration:
                s=duration.split('H')[1].split('S')[0]
        else:
            m=duration.split('H')[1].split('M')[0]
            if 'S' in duration:
                s=duration.split('H')[1].split('M')[1].split('S')[0]
    timeinseconds=int(h)*3600+int(m)*60+int(s)
    return timeinseconds

# %%
#METHOD 3
#FUNCTION: Converts date time string to date
#PURPOSE: used by other methods for conversion to time
from datetime import datetime
from dateutil.parser import parse
def convert_to_date(dt):
    d=parse(dt)
    return d.strftime('%m/%d/%Y')

# %%
#METHOD 4
#FUNCTION: Converts date time string to weeks
#PURPOSE: for finding age of channel
from datetime import datetime
from dateutil.parser import parse
def convert_to_weeks(dt):
    d=parse(dt)
    a=d.strftime('%m/%d/%Y')
    x=datetime.strptime(a, '%m/%d/%Y').date()
    y=datetime.now().date()
    weeks=((y-x).days)/7
    return int(weeks)

# %%
#METHOD 5
#FUNCTION: Cleans text of emoticons
def no_emoji(text):
    RE_EMOJI = re.compile('[\U00010000-\U0010ffff]', flags=re.UNICODE)
    text_no_emoji = RE_EMOJI.sub(r'', text)
    return text_no_emoji

# %%
#METHOD 6
#FUNCTION: gets sentiment of text
#PURPOSE: Used to get sentiment of comments of the video
def get_comment_sentiment(text_emoji):
    text_no_emoji=no_emoji(text_emoji)
    if text_no_emoji is not None and text_no_emoji.strip()!='' and len(text_no_emoji)>3:
        if TextBlob(text_no_emoji).detect_language()=='en':
            blob = TextBlob(text_no_emoji)
            if blob.sentiment.polarity > 0:
                val = "positive"
            elif blob.sentiment.polarity == 0:
                val = "neutral"
            else:
                val = "negative"
        else:
            val=None
    else:
        val= None
    return val

# %%
#METHOD 7
#FUNCTION: to get playlistids
#PURPOSE: fetches the upload playlist of the channel and gets channel statistics
def youtube_channel_videos(channelids):
    youtube = build(YOUTUBE_API_SERVICE_NAME, YOUTUBE_API_VERSION,
                    developerKey=DEVELOPER_KEY)
    playlist_ids=[]
    video_ids=[]
    channelstats={}
    channeldetails = youtube.channels().list(
                         part="snippet,contentDetails,statistics",
                         id=channelids,
                         ).execute()
     
    for i in channeldetails.get('items', []):
        #print(i)
        playlistid=i["contentDetails"]["relatedPlaylists"]["uploads"]
        channelstats[playlistid]=[i['statistics']['viewCount'] if i['statistics'].get('viewCount') is not None else 0,
                                    i['statistics']['subscriberCount'] if i['statistics'].get('subscriberCount') is not None else 0,
                                    i['statistics']['videoCount'] if i['statistics'].get('videoCount') is not None else 0,
                                    convert_to_weeks(i['snippet']['publishedAt']),playlistid]
        if playlistid is not None:
            playlist_ids.append(playlistid) ##Fetching playlist ids of all the channels
    df= youtube_playlist_videos(playlist_ids,channelstats)
    return df

# %%
#METHOD 8
#FUNCTION: gets videos in playlist
#PURPOSE: fetches list of videos in a given playlist
import progressbar
bar = progressbar.ProgressBar()
def youtube_playlist_videos(playlist_ids,channelstats):
    COLUMN_NAMES=['VideoID','Title','Description','Thumbnail','PublishedDate','CategoryID','ChannelID','ChannelTitle',
                  'CHViewCount','CHSubscriberCount','CHAge','CHVideoCount','PlaylistID','Tags','Duration','Caption','ViewCount',
                  'LikeCount','DislikeCount','FavouriteCount','CommentCount']
    dfmain=pd.DataFrame(columns=COLUMN_NAMES)
    youtube = build(YOUTUBE_API_SERVICE_NAME, YOUTUBE_API_VERSION,
                    developerKey=DEVELOPER_KEY)
    for i in playlist_ids:
        video_ids=[] 
        playlistdetails = youtube.playlistItems().list(
                             part="snippet,contentDetails",
                             maxResults=49,
                             playlistId=i
                             ).execute()
        for j in playlistdetails.get('items', []):
            videoid=j["contentDetails"]["videoId"]
            if videoid is not None:
                video_ids.append(videoid) ##Fetching playlist ids of all the channels  
        df=youtube_videos_metadata(','.join(map(str, video_ids)),channelstats[i])

        dfmain=dfmain.append(df)
    return dfmain

# %%
#METHOD 9
#FUNCTION: gets video stats
#PURPOSE: Used to get video stats from videoids and stores the data into dataframe
def youtube_videos_metadata(videoids,channelstats):
    youtube = build(YOUTUBE_API_SERVICE_NAME, YOUTUBE_API_VERSION,
                    developerKey=DEVELOPER_KEY)
    COLUMN_NAMES=['VideoID','Title','Description','Thumbnail','PublishedDate','CategoryID','ChannelID','ChannelTitle',
                  'CHViewCount','CHSubscriberCount','CHAge','CHVideoCount','PlaylistID','Tags','Duration','Caption','ViewCount',
                  'LikeCount','DislikeCount','FavouriteCount','CommentCount']
    dfmain=pd.DataFrame(columns=COLUMN_NAMES)
    i=0
    videos={}
    prev_like=0
    prev_dislike=0
    prev_comm=0
    prev_view=0
    # Call the videos.list method to retrieve location details for each video.
    video_response = youtube.videos().list(
                    part='snippet,contentDetails,statistics',
                    id=videoids
                    ).execute()

    for video_result in video_response.get('items', []):
        dfmain.loc[i]=[video_result['id']
                       ,video_result['snippet']['title']
                       ,video_result['snippet']['description']
                       ,video_result['snippet']['thumbnails']['default']['url']
                       ,convert_to_date(str(video_result['snippet']['publishedAt']))
                       ,video_result['snippet']['categoryId']
                       ,video_result['snippet']['channelId']
                       ,video_result['snippet']['channelTitle']
                       ,channelstats[0]
                       ,channelstats[1]
                       ,channelstats[2]
                       ,channelstats[3]
                       ,channelstats[4]
                       ,', '.join(map(str, video_result['snippet']['tags'])) if video_result['snippet'].get('tags') is not None else ''
                       ,convert_to_seconds(str(video_result['contentDetails']['duration']).replace('PT',''))
                       ,video_result['contentDetails']['caption']
                       ,video_result['statistics']['viewCount'] if video_result['statistics'].get('viewCount') is not None else 0
                       ,video_result['statistics']['likeCount'] if video_result['statistics'].get('likeCount') is not None else 0
                       ,video_result['statistics']['dislikeCount'] if video_result['statistics'].get('dislikeCount') is not None else 0                      
                       ,video_result['statistics']['favoriteCount'] if video_result['statistics'].get('favoriteCount') is not None else 0
                       ,video_result['statistics']['commentCount'] if video_result['statistics'].get('commentCount') is not None else 0
                      ]
        i=int(i)+1
    return dfmain

# %%
#METHOD 10
#FUNCTION: gets video comments
#PURPOSE: Used to get video comment sentiment count for 2 and 7 days and merges it with the dataframe passed as argument  
import progressbar
bar = progressbar.ProgressBar()
def youtube_videos_comments(df):
    youtube = build(YOUTUBE_API_SERVICE_NAME, YOUTUBE_API_VERSION,
                    developerKey=DEVELOPER_KEY)
    COLUMN_NAMES=['VideoID','Comm_count_p7','Comm_count_ng7','Comm_count_n7','Comm_count_p30','Comm_count_ng30','Comm_count_n30']
    dfvideocomments=pd.DataFrame(columns=COLUMN_NAMES)
    video_comments={}
    channel_ids=[]
    i=0
    for index, row in bar(df[VideoID].iterrows()):
    # Call the videos.list method to retrieve location details for each video.
        count_positive2=0;count_negative2=0;count_neutral2=0;count_positive7=0;count_negative7=0;count_neutral7=0;
        try:
            viddate=convert_to_date(row["PublishedDate"])
            comments = youtube.commentThreads().list(
                         part="snippet",
                         videoId=row["VideoID"],
                         textFormat="plainText"
                         ).execute()
            for item in comments["items"]: 
                date=convert_to_date(item["snippet"]["topLevelComment"]["snippet"]["publishedAt"])
                x=datetime.strptime(viddate, '%m/%d/%Y').date()
                y=datetime.strptime(date, '%m/%d/%Y').date()
                days=(y-x).days
                if days <=2:
                    comment = item["snippet"]["topLevelComment"]["snippet"]["textDisplay"]
                    sentiment=get_comment_sentiment(comment)
                    if sentiment=='positive':
                        count_positive2=count_positive2+1
                        count_positive7=count_positive7+1
                    elif sentiment=='negative':
                        count_negative2=count_negative2+1
                        count_negative7=count_negative7+1
                    elif sentiment=='neutral':
                        count_neutral2=count_neutral2+1
                        count_neutral7=count_neutral7+1
                    else:
                        continue
                elif days<=7:
                    comment = item["snippet"]["topLevelComment"]["snippet"]["textDisplay"]
                    sentiment=get_comment_sentiment(comment)
                    if sentiment=='positive':
                        count_positive7=count_positive7+1
                    elif sentiment=='negative':
                        count_negative7=count_negative7+1
                    elif sentiment=='neutral':
                        count_neutral7=count_neutral7+1
                    else:
                        continue

            dfvideocomments.loc[i]=[item["snippet"]["videoId"],count_positive7,count_negative7,count_neutral7,count_positive30,
                                    count_negative30,count_neutral30]
            i=int(i)+1
        except:
            continue
    dfresult = pd.merge(df, dfvideocomments, how='inner', on=['VideoID', 'VideoID'])
    return dfresult
# Out:
# - |#                                                  | 0 Elapsed Time: 0:00:00

# %%
#METHOD 11
#FUNCTION: Main method-Starting point
#PURPOSE: Used to get input search term from user and then gets video stats after which calls the method to get comment sentiment
#count
import argparse
search_term=input("Kindly enter search term :")
num_of_pages= input("Enter number of pages :")
vid_ids=''
COLUMN_NAMES=['VideoID','Title','Description','Thumbnail','PublishedDate','CategoryID','ChannelID','ChannelTitle',
                  'CHViewCount','CHSubscriberCount','CHAge','CHVideoCount','PlaylistID','Tags','Duration','Caption','ViewCount',
                  'LikeCount','DislikeCount','FavouriteCount','CommentCount']
dfmain1=pd.DataFrame(columns=COLUMN_NAMES)

if __name__ == '__main__':
    parser = argparse.ArgumentParser()
    parser.add_argument('--q', help='Search term', default=search_term)
    parser.add_argument('--max-results', help='Max results', default=40)
    args = parser.parse_args(args=[])
    channelids=youtube_channel_search(args, num_of_pages)
    channel_ids=''
    a=0
    start=0
    end=49
    playlistvidscaptions={}
    len_cha=int(len(channelids)/50)
    print(len_cha)
    for x in range(a,len_cha+1): 
        print(x)
        channel_ids=''
        for index,val in enumerate(channelids[start:end]):  
            if index==48:
                channel_ids = channel_ids+','+val
                start=start+49
                end=end+49
                break
            else:
                channel_ids = channel_ids+','+val
        channelplaylistsvideos=youtube_channel_videos(str(channel_ids[1:]))  
        dfmain1=dfmain1.append(channelplaylistsvideos)
    writer = pd.ExcelWriter('D:/knowledge/college docs/DSP/Project2/FinalVideoList.xlsx')
    dfmain1.to_excel(writer)
    writer.save()
    print('fetching comments!')
    dffinal=youtube_videos_comments(dfmain1)
    writer1 = pd.ExcelWriter('D:/knowledge/college docs/DSP/Project2/FinalVideoListCommentInfo.xlsx')
    dffinal.to_excel(writer1)
    writer1.save()
# Out:
# Kindly enter search term :food
# Enter number of pages :8
# 6
# 0
# 1
# 2
# 3
# 4
# 5
# 6
# C:\Users\AdrianFcBarcelona\Anaconda3\lib\site-packages\xlsxwriter\worksheet.py:830: UserWarning: Ignoring URL 'https://www.buzzfeed.com/marietelling/brown-butter-chocolate-chip-cookies
#
# Shop%20the%20Tasty%20kitchenware%20collection%20here:%20http://bit.ly/2IooLS4
#
# Check%20us%20out%20on%20Facebook!%20-%20facebook.com/buzzfeedtasty
#
# Credits:%20https://www.buzzfeed.com/bfmp/videos/46066
#
#
# MUSIC
# Giraffe%20Bossa_fullmix%20(1)
# Licensed%20via%20Warner%20Chappell%20Production%20Music%20Inc.
# Monte%20Fiasco_Main
# Licensed%20via%20Warner%20Chappell%20Production%20Music%20Inc.' with link or location/anchor > 255 characters since it exceeds Excel's limit for URLS
#   force_unicode(url))
# C:\Users\AdrianFcBarcelona\Anaconda3\lib\site-packages\xlsxwriter\worksheet.py:830: UserWarning: Ignoring URL 'https://www.buzzfeed.com/marietelling/how-to-make-risotto?utm_term=.beNOOPok8' with link or location/anchor > 255 characters since it exceeds Excel's limit for URLS
#   force_unicode(url))
# C:\Users\AdrianFcBarcelona\Anaconda3\lib\site-packages\xlsxwriter\worksheet.py:830: UserWarning: Ignoring URL 'http://bit.ly/HJFBaconTips%20sponsored%20by%20Oscar%20Mayer
# Bread%20is%20overrated,%20make%20bacon%20be%20the%20tool%20to%20drive%20food%20into%20your%20mouth.%20%20' with link or location/anchor > 255 characters since it exceeds Excel's limit for URLS
#   force_unicode(url))
# C:\Users\AdrianFcBarcelona\Anaconda3\lib\site-packages\xlsxwriter\worksheet.py:830: UserWarning: Ignoring URL 'http://vk.com/fastfoodmusic
# http://fastfoodmusic.com/
#
# Night%20Lovell:
# https://twitter.com/nightlovell
# https://www.instagram.com/nightlovell/
# https://soundcloud.com/night_lovell
# http://vk.com/nightlovell_public%20(Fan%20Page)
#
# Directed%20by%20Dima%20Melrose%20-%20%20https://vk.com/dmitry.melrose
#
# —%20Выступления%20%5bLive%20performances%5d%20(01:03)
# —%20Любовь%20к%20России%20%5bLove%20to%20Russia%5d%20(02:50)
# —%20Личная%20жизнь%20%5bPersonal%20life%5d%20(04:51)
# —%20Лейблы%20%5bRecord%20labels%5d%20(06:08)
# —%20Вдохновение%20во%20время%20записи%20«Red%20Teenage%20Melody»%20%5bInfluences%20while%20recording%20«Red%20Teenage%20Melody»%5d%20(08:07)
# —%20Клипы%20%5bMusic%20videos%5d%20(10:07)
# —%20Современная%20андерграундная%20сцена%20%5bModern%20underground%20rap%20scene%5d%20(11:40)
# —%20Запись%20музыки%20%5bThe%20recording%20process%5d%20(13:14)
# —%20Отношения%20с%20девушками%20%5bRelationships%20with%20girls%5d%20(16:45)
# —%20Наркотики%20%5bDrugs%5d%20(18:09)
# —%20Мини-альбом%20с%20Misogi%20%5bCollaborative%20EP%20with%20Misogi%5d%20(19:05)
# —%20Любимый%20альбом%20за%202017%20год%20%5bFavorite%20album%20of%202017%5d%20(19:55)
# —%20Россия%20—%20второй%20дом%20%5bRussia%20is%20his%20second%20home%5d%20(20:44)' with link or location/anchor > 255 characters since it exceeds Excel's limit for URLS
#   force_unicode(url))
# C:\Users\AdrianFcBarcelona\Anaconda3\lib\site-packages\xlsxwriter\worksheet.py:830: UserWarning: Ignoring URL 'http://vk.com/fastfoodmusic
# http://fastfoodmusic.com/
#
# DOPECLVB:
# https://vk.com/dopeclvb
# https://www.youtube.com/channel/UCS9Rx7Thy7lnTBlt1TATZlw
#
# i61:
# https://vk.com/sixone
# https://twitter.com/i61i61i61
# https://www.instagram.com/i61i61i61i61i61i61i61i61/
# https://soundcloud.com/i61
#
# GLEBASTA%20SPAL:
# https://vk.com/gsclvb
# https://twitter.com/glebastaspal
# https://www.instagram.com/glebasta_spal/
# https://soundcloud.com/glebastaspal
#
# Basic%20Boy:
# https://vk.com/baecyq
# https://twitter.com/basiqboy
# https://www.instagram.com/baesiqq/
#
# Nickie%20Zimov:
# https://vk.com/nickiezimov
# https://vk.com/id18793377
# https://twitter.com/nickiezimov
# https://www.instagram.com/nickiezimov/
#
# Оператор:%20Глеб%20Кузнецов%20(https://vk.com/glleb)' with link or location/anchor > 255 characters since it exceeds Excel's limit for URLS
#   force_unicode(url))
# C:\Users\AdrianFcBarcelona\Anaconda3\lib\site-packages\xlsxwriter\worksheet.py:830: UserWarning: Ignoring URL 'http://vk.com/fastfoodmusic
# http://fastfoodmusic.com/
#
# Jazz%20Cartier:
# https://twitter.com/jazzcartier
# https://www.instagram.com/jacuzzilafleur/
# https://www.youtube.com/channel/UCAWYcxTePOFz4rCANq5Ymdw
# https://soundcloud.com/jazzcartier
# https://vk.com/jacuzzilafleur%20(Fan%20Page)
#
# Оператор:%20Дмитрий%20Ивашин%20(https://vk.com/dmitry.melrose)
#
# —%20Хип-хоп-индустрия%20в%20Канаде%20%5bHip-hop%20industry%20in%20Canada%5d%20(00:27)
# —%20Путешествия%20%5bJourneys%5d%20(00:59)
with link or location/anchor > 255 characters since it exceeds Excel's limit for URLS
#   force_unicode(url))
# C:\Users\AdrianFcBarcelona\Anaconda3\lib\site-packages\xlsxwriter\worksheet.py:830: UserWarning: Ignoring URL 'http://vk.com/fastfoodmusic
# http://fastfoodmusic.com/
#
# Night%20Lovell:
# https://twitter.com/nightlovell
# https://www.instagram.com/nightlovell/
# https://soundcloud.com/night_lovell
# http://vk.com/nightlovell_public%20(Fan%20Page)
#
# —%20Рэп-индустрия%20в%20Канаде%20%5bRap%20industry%20in%20Canada%5d%20(00:12)
# —%20Оттава%20%5bOttawa%5d%20(01:30)
# —%20Аудитория%20%5bAudience%5d%20(02:03)
# —%20Времена%20KLNV,%20начало%20карьеры%20%5bKLNV%20days,%20the%20beginning%20of%20the%20career%5d%20(02:51)
# —%20Источники%20вдохновения%20%5bSources%20of%20inspiration%5d%20(04:23)
# —%20Предпочтения%20в%20одежде%20%5bFashion%20preferences%5d%20(04:47)
# —%20Некий%20Данте%20из%20трека%20«Fraud»%20%5bSomebody%20named%20Dante%20from%20the%20song%20«Fraud»%5d%20(05:51)
# —%20Времяпрепровождение%20в%20Оттаве%20%5bHow%20does%20he%20spend%20time%20in%20Ottawa%5d%20(06:29)
# —%20Ненависть%20к%20родному%20городу%20%5bHate%20towards%20his%20own%20city%5d%20(07:07)
# —%20Образование%20%5bEducation%5d%20(07:54)
# —%20Дальнейшие%20планы%20в%20музыке%20%5bFuture%20plans%20in%20music%5d%20(08:44)
# —%20Коллаборации%20с%20другими%20артистами%20%5bCollaborations%20with%20other%20artists%5d%20(10:07)
# —%20Впечатления%20от%20Англии,%20Франции%20и%20России%20%5bImpressions%20from%20England,%20France%20and%20Russia%5d%20(12:25)' with link or location/anchor > 255 characters since it exceeds Excel's limit for URLS
#   force_unicode(url))
# C:\Users\AdrianFcBarcelona\Anaconda3\lib\site-packages\xlsxwriter\worksheet.py:830: UserWarning: Ignoring URL 'http://vk.com/fastfoodmusic
# https://vk.com/fortnoxznaal
# https://vk.com/deaddynasty
# http://fastfoodmusic.com/
#
# —%20Поиск%20своего%20стиля%20(00:05)
# —%20Концепция%20релизов%20(00:53)
# —%20Персонажи,%20задействованные%20в%20сюжете%20(01:25)
# —%20«Тихие%20комнаты»%20(02:15)
# —%20Что%20должно%20измениться%20в%20обществе?%20(03:09)
# —%20Тема%20религии%20в%20текстах%20(04:20)
# —%20История%20создания%20трека%20«Адонай»%20(05:17)
# —%20«Азибо»:%20задумка%20(06:10)
# —%20Множественная%20личность%20(07:18)
# —%20Слоны%20в%20качестве%20символа%20(07:43)
# —%20Длительные%20перерывы%20между%20релизами%20(08:29)
# —%20Отношение%20к%20творчеству,%20мнение%20окружающих%20(08:54)
# —%20Раскрытие%20характеров%20персонажей,%20музыкальная%20режиссура%20(09:35)
# —%20Впечатления%20от%20тура%20«YUNGRUSSIA%20SHOWCASE%20TOUR»%20(10:56)
# —%20Первая%20публикация%20на%20крупном%20ресурсе%20(12:39)
# —%20Отношение%20к%20баттл-рэпу%20(13:40)
# —%20Дальнейшее%20развитие%20индустрии%20(14:29)' with link or location/anchor > 255 characters since it exceeds Excel's limit for URLS
#   force_unicode(url))
# C:\Users\AdrianFcBarcelona\Anaconda3\lib\site-packages\xlsxwriter\worksheet.py:830: UserWarning: Ignoring URL 'http://fastfoodmusic.com/
# http://vk.com/fastfoodmusic
#
# —%20Возникновение%20экстраординарного%20образа%20(00:00)
# —%20Музыкальная%20сцена%20в%20Эстонии%20(00:30)
# —%20Минимализм%20(01:29)
# —%20Выступление%20Рианны%20и%20Канье%20Уэста%20в%20Эстонии%20(01:54)
# —%20Как%20правильно%20ухаживать%20за%20ковром%20(02:18)
# —%20Как%20правильно%20гладить%20полоски%20на%20костюме%20«adidas»%20(02:54)
# —%20«Евровидение»%20(03:28)
# —%20Выступления%20на%20телевидении%20(03:56)
# —%20Первое%20приобретение%20на%20деньги%20от%20творчества%20(04:32)
with link or location/anchor > 255 characters since it exceeds Excel's limit for URLS
#   force_unicode(url))
# C:\Users\AdrianFcBarcelona\Anaconda3\lib\site-packages\xlsxwriter\worksheet.py:830: UserWarning: Ignoring URL 'http://www.shebayemenifood.com/recipes/basbousa
# http://www.facebook.com/shebayemenifood
# http://instagram.com/shebayemenifood
# http://twitter.com/shebayemenifood
#
# Ingredients
# Basbousa%20Cake
# 2%20cups%20coarse%20semolina
# 1/4%20cup%20fine%20semolina
# 1/2%20cup%20butter,%20melted
# 1%20cup%20unsweetened%20yogurt
# 3/4%20cup%20sugar
# 1/4%20tsp.%20salt
# 1/2%20tsp.%20baking%20soda
# almonds,%20about%2020%20whole
#
# Sugar%20syrup
# 2%20cups%20sugar
# 2%20cups%20water
# 1%20tsp.%20flavor%20(orange%20blossom%20or%20rose%20water)
# cardamom%20pods%20(optional)' with link or location/anchor > 255 characters since it exceeds Excel's limit for URLS
#   force_unicode(url))
# C:\Users\AdrianFcBarcelona\Anaconda3\lib\site-packages\xlsxwriter\worksheet.py:830: UserWarning: Ignoring URL 'http://www.shebayemenifood.com/recipes/red-lentil-soup
# http://www.facebook.com/shebayemenifood
# http://instagram.com/shebayemenifood
# http://twitter.com/shebayemenifood
#
# مكونات
#
# 3/4%20كوب%20عدس
# 1/4%20كوب%20صلصه%20طماطم
# نصف%20بصل%20مفروم
# 3%20ملاعق%20كبير%20زيت
# اثنين%20فصوص%20ثم
# 1/2%20ملعقه%20ملح%20او%20حسب%20الذوق
# رشه%20كمون
# رشه%20كركم
# 4%20اكواب%20ماء%20او%20مرق' with link or location/anchor > 255 characters since it exceeds Excel's limit for URLS
#   force_unicode(url))
# C:\Users\AdrianFcBarcelona\Anaconda3\lib\site-packages\xlsxwriter\worksheet.py:830: UserWarning: Ignoring URL 'http://www.shebayemenifood.com/recipes/red-lentil-soup
# http://www.facebook.com/shebayemenifood
# http://instagram.com/shebayemenifood
# http://twitter.com/shebayemenifood
#
# Ingredients
# %203/4%20%20cup%20lentils,%20washed
# %201/4%20cup%20tomato%20sauce
# %201/2%20onion,%20chopped
# %203%20tbsp.%20oil
# %201/2%20to%201%20tsp.%20salt
# %202%20cloves%20of%20garlic,%20minced
# %20pinch%20cumin%20seeds
# %20pinch%20turmeric,%20optional
# %204%20cups%20water' with link or location/anchor > 255 characters since it exceeds Excel's limit for URLS
#   force_unicode(url))
# C:\Users\AdrianFcBarcelona\Anaconda3\lib\site-packages\xlsxwriter\worksheet.py:830: UserWarning: Ignoring URL 'http://www.shebayemenifood.com/
# http://www.facebook.com/shebayemenifood
# http://instagram.com/shebayemenifood
# http://twitter.com/shebayemenifood
#
# Ingredients
# 1%20cup%20butter,%20softened
# 2%203/4%20cup%20sugar
# 6%20eggs
# 3%20cups%20of%20flour
# 1/2%20tsp.%20salt
# 1/4%20tsp.%20baking%20soda
# 1%20cup%20of%20sour%20cream
# 1%20tsp.%20of%20flavoring%20(vanilla,%20lemon,%20etc.)' with link or location/anchor > 255 characters since it exceeds Excel's limit for URLS
#   force_unicode(url))
# C:\Users\AdrianFcBarcelona\Anaconda3\lib\site-packages\xlsxwriter\worksheet.py:830: UserWarning: Ignoring URL 'http://www.shebayemenifood.com/
# http://www.facebook.com/shebayemenifood
# http://instagram.com/shebayemenifood
# http://twitter.com/shebayemenifood
#
# مكونات
# كوب%20زبدة
# 2%20و%203/4%20كوب%20سكر
# 6%20بيض
# 3%20أكواب%20من%20الدقيق
# 1/2%20ملعقة%20صغيرة%20من%20الملح
# 1/4%20ملعقة%20صغيرة%20من%20البكنغ%20صودا
# كوب%20من%20الكريمه%20الحامضة
#  %20ملعقة%20صغيرة%20من%20نكهة' with link or location/anchor > 255 characters since it exceeds Excel's limit for URLS
#   force_unicode(url))
# C:\Users\AdrianFcBarcelona\Anaconda3\lib\site-packages\xlsxwriter\worksheet.py:830: UserWarning: Ignoring URL 'http://www.shebayemenifood.com/recipes/muqasqas
# http://www.facebook.com/shebayemenifood
# http://instagram.com/shebayemenifood
# http://twitter.com/shebayemenifood
#
# مقادير
# 2%20كوب%20دقيق
# 1/2%20كوب%20+%202%20ملاعق%20كبير%20سمن
# 1/4%20ملاعقه%20صغيره%20ملح
# 1%20ملاعقه%20صغيره%20سكر
# 1%20ملاعقه%20صغيره%20حبه%20سودا
# 1/4-1/3%20كوب%20ماء' with link or location/anchor > 255 characters since it exceeds Excel's limit for URLS
#   force_unicode(url))
# C:\Users\AdrianFcBarcelona\Anaconda3\lib\site-packages\xlsxwriter\worksheet.py:830: UserWarning: Ignoring URL 'http://www.shebayemenifood.com
# http://www.facebook.com/shebayemenifood
# http://instagram.com/shebayemenifood
# http://twitter.com/shebayemenifood
#
# %20المقادير
#
# 2%20بيض
# 1%20كوب%20دقيق
# 1%201/2%20كوب%20حليب
# 4%20ملاعق%20كبيره%20زيت
# 2%20%20ملاعق%20كبير%20سكر
# 6%20ملاعق%20صغير%20خميره%20بيكينج%20بودر
# 1%20ملاعقه%20شاي%20ملح' with link or location/anchor > 255 characters since it exceeds Excel's limit for URLS
#   force_unicode(url))
# C:\Users\AdrianFcBarcelona\Anaconda3\lib\site-packages\xlsxwriter\worksheet.py:830: UserWarning: Ignoring URL 'http://www.shebayemenifood.
#
# https://www.facebook.com/GreatAmericanEatOff/videos/1692410737505774/?hc_location=ufi
#
#
# Their%20Page:
# https://www.facebook.com/bmppnorthridge/
#
# Address:
# 8323%20Reseda%20Blvd,%20Unit%20101%20
# Northridge,%20California%2091324
#
# Details%20of%20the%20Contest:
# Finish%20the%20pizza%20within%202%20hours;%20get%20it%20for%20free;%20plus%20$1000!
#
# Participants:
# Naader(Freakeating)%20
# Jimmy%20(The%20Spiciliast)%20Lin
# Kevin%20Ross
# Taran%20Eckel
# Aubrey
# Gail%20Kaspa
# Eric%20Lu%20(jumped%20in%20at%20last%20second!)%20
#
# So%20we’re%20eating%20for%20Pawtographs%20(pawtographs.org)
# To%20raise%20awareness%20for%20animals%20and%20rescues;%20as%20well%20as%20promoting%20H.Res.677%20:)%20Hope%20you%20enjoy;%20I%20tried%20to%20condense%20so%20it%20wouldn’t%20be%20boring%20but%20check%20out%20the%20live%20stream%20if%20you%20wanna%20hear%20the%20conversations/etc!
#
#
# Thank%20you%20for%20the%20support!!
#
# Email%20Q%20and%20A%20and%20pictures%20to:%20
# rainahuang94@yahoo.com
#
# Send%20me%20stuff-%20My%20PO%20Box%20:)
#
# 20687%20Amar%20Rd%20Ste%202-196
# Walnut,%20CA%2091789
#
#
#
# My%20Social%20Media:%20
#
# Facebook%20Page:%20https://www.facebook.com/RainaHuang/
# Twitter:%20https://twitter.com/omgitzraina?lang=en
# Insta:%20https://www.instagram.com/rainaiscrazy' with link or location/anchor > 255 characters since it exceeds Excel's limit for URLS
#   force_unicode(url))
# C:\Users\AdrianFcBarcelona\Anaconda3\lib\site-packages\xlsxwriter\worksheet.py:830: UserWarning: Ignoring URL 'http://paypal.me/rainahuang%20
# https://www.patreon.com/RainaisCrazy
#
# Like%20my%20videos?%20Support%20my%20food%20adventures!!%20Donate%20to%20me%20directly%20via%20PayPal%20or%20become%20a%20Patreon!%20Sometimes%20my%20challenges%20aren’t%20free%20and%20also%20helps%20for%20the%20gas;%20I%20have%20to%20drive%20a%20lot%20to%20get%20to%20the%20location%20sometimes….also%20for%20equipment%20for%20future%20development%20of%20my%20videos!
#
# My%20very%20first%20vlog-type%20of%20video%20:)%20I%20took%20Baa-Chan%20out%20to%20Mo-Mo%20Paradise%20cuz%20I%20felt%20like%20she%20would%20really%20enjoy%20this%20type%20of%20food...and%20she%20did%20%5e_%5e%20even%20though%20she%20said%20she%20wasn't%20hungry%20earlier%20haha%20Hope%20you%20guys%20enjoy%20it!
#
# Their%20Page:
# https://www.facebook.com/momoparadiserowlandheights/
#
# Address:
#
# 17596%20Colima%20Rd%20
# Rowland%20Heights,%20California%2091748
#
#
#
# Thank%20you%20for%20the%20support!!
#
# Email%20Q%20and%20A%20and%20pictures%20to:%20
# rainahuang94@yahoo.com
#
# Send%20me%20stuff-%20My%20PO%20Box%20:)
#
# 20687%20Amar%20Rd%20Ste%202-196
# Walnut,%20CA%2091789
#
#
# ♫Music%20By♫
# Song:%20Joakim%20Karud%20-%20Good%20Old%20Days%20(Vlog%20No%20Copyright%20Music)
# Music%20provided%20by%20Vlog%20No%20Copyright%20Music.
# Video%20Link:%20https://youtu.be/Zl3r_HPulLk
#
# My%20Social%20Media:%20
#
# Facebook%20Page:%20https://www.facebook.com/RainaHuang/
# Twitter:%20https://twitter.com/omgitzraina?lang=en
# Insta:%20https://www.instagram.com/rainaiscrazy' with link or location/anchor > 255 characters since it exceeds Excel's limit for URLS
#   force_unicode(url))
# C:\Users\AdrianFcBarcelona\Anaconda3\lib\site-packages\xlsxwriter\worksheet.py:830: UserWarning: Ignoring URL 'http
#
# Like%20and%20subscribe%20the%20video%20if%20you%20enjoyed%20it%20:)
#
# Thank%20you%20for%20the%20support!!
#
# Send%20me%20stuff-%20My%20PO%20Box%20:)
#
# 20687%20Amar%20Rd%20Ste%202-196
# Walnut,%20CA%2091789
#
#
# My%20Social%20Media:%20
#
# Facebook%20Page:%20https://www.facebook.com/RainaHuang/
# Twitter:%20https://twitter.com/omgitzraina?lang=en
# Insta:%20https://www.instagram.com/rainahuang94/
#
# Paypal%20Donators:%20
# Gianni
# Khaled
# Steve
# Sebastian
# James
# CELLULAR%20KING
# JMC%20Enterprises
# Ingrid
# John' with link or location/anchor > 255 characters since it exceeds Excel's limit for URLS
#   force_unicode(url))
# C:\Users\AdrianFcBarcelona\Anaconda3\lib\site-packages\xlsxwriter\worksheet.py:830: UserWarning: Ignoring URL 'http://paypal.me/rainahuang
#
# Like%20my%20videos?%20Support%20my%20food%20adventures!!%20Sometimes%20my%20challenges%20aren’t%20free%20and%20also%20helps%20for%20the%20gas;%20I%20have%20to%20drive%20a%20lot%20to%20get%20to%20the%20location%20sometimes….also%20for%20equipment%20for%20future%20development%20of%20my%20videos!
#
# 2018%20TET%20Pho%20Eating%20Competition!%20
# https://www.facebook.com/TetFestival/
#
# I%20never%20knew%20that%20the%20Vietnamese%20New%20Year%20was%20referred%20to%20the%20“TET”%20Festival….I%20really%20enjoy%20learning%20about%20so%20much%20culture….
#
# It%20was%20so%20fun%20walking%20around%20and%20looking%20at%20Vietnamese%20cultural%20heritage…from%20the%20food%20,%20the%20clothing,%20the%20dancing,%20and%20everything%20else%20:)%20All%20the%20staff%20and%20volunteers%20were%20so%20friendly%20and%20supportive,%20thank%20you%20for%20setting%20up%20such%20an%20amazing%20festival%20for%20everyone%20to%20enjoy!
#
# Thank%20you%20for%20the%20support!!
#
# Send%20me%20stuff-%20My%20PO%20Box%20:)
#
# 20687%20Amar%20Rd%20Ste%202-196
# Walnut,%20CA%2091789
#
# My%20Social%20Media:%20
#
# Facebook%20Page:%20https://www.facebook.com/RainaHuang/
# Twitter:%20https://twitter.com/omgitzraina?lang=en
# Insta:%20https://www.instagram.com/rainahuang94/
#
# Paypal%20Donators:%20
# Gianni
# Khaled
# Steve
# Sebastian
# James
# CELLULAR%20KING
# JMC%20Enterprises
# Ingrid' with link or location/anchor > 255 characters since it exceeds Excel's limit for URLS
#   force_unicode(url))
# C:\Users\AdrianFcBarcelona\Anaconda3\lib\site-packages\xlsxwriter\worksheet.py:830: UserWarning: Ignoring URL 'http://paypal.me/rainahuang
#
# Like%20my%20videos?%20Support%20my%20food%20adventures!!%20Sometimes%20my%20challenges%20aren’t%20free%20and%20also%20helps%20for%20the%20gas;%20I%20have%20to%20drive%20a%20lot%20to%20get%20to%20the%20location%20sometimes….also%20for%20equipment%20for%20future%20development%20of%20my%20videos!
#
# Please%20Check%20out%20Reckless%20Eating
# https://www.youtube.com/watch?v=suy-LRfivEo
#
# and%20Cue%20the%20Critic%20who%20also%20took%20on%20the%20burrito!
# https://www.youtube.com/watch?v=8pHDnlqIPHY
#
# Their%20Facebook%20Page:
# https://www.facebook.com/tacohut4u/
#
# Address:
# 11815%20Foothill%20Blvd%20
# Rancho%20Cucamonga,%20California%2091730
#
# Details%20of%20the%20Contest:
#
# Finish%20a%202.5lb%20Burrito%20and%20beat%20the%20current%20record%20to%20get%20it%20for%20free,%20and%20also%20a%20T-shirt,%20and%20Picture%20on%20hall%20of%20fame!!
